# %%
import pandas as pd
import random
from matplotlib import pyplot as plt

# %%
def right_orientation():
    if random.randint(1, 6) >= 4:
        return True
    return False

# %%
def simulation(collisions, sides):
    effective_collisions = 0
    activation_energy = []
    for i in range(2, (2 *sides) + 1):
        activation_energy.append(i)
    effective_collisions = [0] * ((sides * 2) - 1)
    maxwell_boltzman = [0] * ((sides * 2) - 1)
    
    for i in range(collisions):
            particle_energy1 = random.randint(1, sides) + random.randint(1, sides)
            particle_energy2 = random.randint(1, sides) + random.randint(1, sides)
            maxwell_boltzman[particle_energy1 - 2] += 1
            maxwell_boltzman[particle_energy2 - 2] += 1
            if not right_orientation(): continue
            for curr_activation in activation_energy:
                if particle_energy1 >= curr_activation and particle_energy2 >= curr_activation:
                    effective_collisions[curr_activation - 2] += 1
                else:
                    break
    return maxwell_boltzman, effective_collisions

# %% [markdown]
# # Low Temp

# %% [markdown]
# ### 2000000 Particles

# %%
data = simulation(1000000, 6)
x = [i for i in range(2, 13)]

# %%
plt.plot(x, data[0])
plt.xlabel("Kinetetic Energy")
plt.ylabel("# Particles")
plt.title("Maxwell Boltzmann Distribution at Low Temp")
plt.show()

# %%
plt.bar(x, data[0])
plt.xlabel("Kinetetic Energy")
plt.ylabel("# Particles")
plt.title("Maxwell Boltzmann Distribution at Low Temp")
plt.show()

# %%
# activation energy vs effective collisions
plt.plot(x, data[1])
plt.xlabel("Activation Energy")
plt.ylabel("# Particles")
plt.title("Activation Energy vs # Particles at Low Temp")
plt.show()

# %% [markdown]
# ### 2000 Particles

# %%
data = simulation(1000, 6)

# %%
plt.plot(x, data[0])
plt.xlabel("Kinetetic Energy")
plt.ylabel("# Particles")
plt.title("Maxwell Boltzmann Distribution at Low Temp")
plt.show()

# %%
plt.bar(x, data[0])
plt.xlabel("Kinetetic Energy")
plt.ylabel("# Particles")
plt.title("Maxwell Boltzmann Distribution at Low Temp")
plt.show()

# %%
# activation energy vs effective collisions
plt.plot(x, data[1])
plt.xlabel("Activation Energy")
plt.ylabel("# Particles")
plt.title("Activation Energy vs # Particles at Low Temp")
plt.show()

# %%
data[1]
# Out:
# [497, 470, 427, 351, 268, 188, 90, 50, 17, 4, 0]

# %% [markdown]
# ### 40 Particles

# %%
data = simulation(20, 6)

# %%
plt.plot(x, data[0])
plt.xlabel("Kinetetic Energy")
plt.ylabel("# Particles")
plt.title("Maxwell Boltzmann Distribution at Low Temp")
plt.show()

# %%
plt.bar(x, data[0])
plt.xlabel("Kinetetic Energy")
plt.ylabel("# Particles")
plt.title("Maxwell Boltzmann Distribution at Low Temp")
plt.show()

# %%
# activation energy vs effective collisions
plt.plot(x, data[1])
plt.xlabel("Activation Energy")
plt.ylabel("# Particles")
plt.title("Activation Energy vs # Particles at Low Temp")
plt.show()

# %% [markdown]
# # High Temp

# %% [markdown]
# ### 2000000 Particles

# %%
data = simulation(1000000, 10)
x = [i for i in range(2, 21)]

# %%
plt.plot(x, data[0])
plt.xlabel("Kinetetic Energy")
plt.ylabel("# Particles")
plt.title("Maxwell Boltzmann Distribution at High Temp")
plt.show()

# %%
plt.bar(x, data[0])
plt.xlabel("Kinetetic Energy")
plt.ylabel("# Particles")
plt.title("Maxwell Boltzmann Distribution at High Temp")
plt.show()

# %%
# activation energy vs effective collisions
plt.plot(x, data[1])
plt.xlabel("Activation Energy")
plt.ylabel("# Particles")
plt.title("Activation Energy vs # Particles at High Temp")
plt.show()

# %% [markdown]
# ### 2000 Particles

# %%
data = simulation(1000, 10)

# %%
plt.plot(x, data[0])
plt.xlabel("Kinetetic Energy")
plt.ylabel("# Particles")
plt.title("Maxwell Boltzmann Distribution at High Temp")
plt.show()

# %%
plt.bar(x, data[0])
plt.xlabel("Kinetetic Energy")
plt.ylabel("# Particles")
plt.title("Maxwell Boltzmann Distribution at High Temp")
plt.show()

# %%
# activation energy vs effective collisions
plt.plot(x, data[1])
plt.xlabel("Activation Energy")
plt.ylabel("# Particles")
plt.title("Activation Energy vs # Particles at High Temp")
plt.show()

# %%
data[1]
# Out:
# [488,
#  474,
#  454,
#  435,
#  400,
#  359,
#  305,
#  258,
#  212,
#  157,
#  104,
#  65,
#  40,
#  25,
#  10,
#  4,
#  2,
#  0,
#  0]

# %% [markdown]
# ### 40 Particles

# %%
data = simulation(20, 10)

# %%
plt.plot(x, data[0])
plt.xlabel("Kinetetic Energy")
plt.ylabel("# Particles")
plt.title("Maxwell Boltzmann Distribution at High Temp")
plt.show()

# %%
plt.bar(x, data[0])
plt.xlabel("Kinetetic Energy")
plt.ylabel("# Particles")
plt.title("Maxwell Boltzmann Distribution at High Temp")
plt.show()

# %%
# activation energy vs effective collisions
plt.plot(x, data[1])
plt.xlabel("Activation Energy")
plt.ylabel("# Particles")
plt.title("Activation Energy vs # Particles at High Temp")
plt.show()
